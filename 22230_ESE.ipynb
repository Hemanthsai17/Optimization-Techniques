# %% [markdown]
# 1. Wilson Problem:
# Wilson Manufacturing produces both baseballs and softballs, which it wholesales to vendors around the country. Its facilities permit the manufacture of a maximum of 500 dozen baseballs and a maximum of 500 dozen softballs each day. The cowhide covers for each ball are cut from the same processed cowhide sheets. Each dozen baseballs require five square feet of cowhide (including waste), whereas, one dozen softballs require six square feet of cowhide (including waste). Wilson has 3600 square feet of cowhide sheets available each day.Production of baseballs and softballs includes making the inside core, cutting and sewing the cover, and packaging. It takes about one minute to manufacture a dozen baseballs and two minutes to manufacture a dozen softballs. A total of 960 minutes is available for production daily. The prices for a dozen baseball and a dozen softball are 7 and 10 dollars respectively.
#
# Answer the following:

# %%
a) Formulate the problem in the Excel file and generate the sensitivity analysis.

# %% [markdown]
# ![Annotation%202022-11-14%20161615.png](attachment:Annotation%202022-11-14%20161615.png)

# %% [markdown]
# ![Annotation%202022-11-14%20161706.png](attachment:Annotation%202022-11-14%20161706.png)

# %%
b) Write on cost coefficient sensitivity analysis.

# %%
c) Write on Right Hand Side Sensitivity Analysis.

# %% [markdown]
# ![Annotation%202022-11-14%20161702.png](attachment:Annotation%202022-11-14%20161702.png)

# %% [markdown]
# d) Solve the formulated LP problem using scipy.optimise and verify your solution with the solution (a).

# %%
import scipy
from scipy import optimize
scipy.optimize.nonlin
# Out:
# <module 'scipy.optimize.nonlin' from 'C:\\Users\\Msc 1\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\scipy\\optimize\\nonlin.py'>

# %%
o=[7,10]
c=[[1,1],[5,6],[1,2]]
b=[1000,3600,960]
scipy.optimize.linprog(o,c,b)
# Out:
#      con: array([], dtype=float64)
#      fun: 1.6699186800392368e-09
#  message: 'Optimization terminated successfully.'
#      nit: 9
#    slack: array([1000., 3600.,  960.])
#   status: 0
#  success: True
#        x: array([1.77711417e-10, 4.25938759e-11])

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 2. Consider the following problem:
# 𝑓(𝑥1, 𝑥2) = 4𝑥1 + 6𝑥2 − 2𝑥12 − 2𝑥1𝑥2 − 2𝑥22

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# a) Write a program to visualize above function.

# %% [markdown]
# b) Write a iterative program to solve the problem
